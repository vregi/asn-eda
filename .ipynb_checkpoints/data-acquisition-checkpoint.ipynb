# %% [markdown]
# # Data Acquisition for Exploratory Data Analysis of Aviation Accidents

# %% [markdown]
# This notebook documents the acquisition of the aviation accidents dataset from Aviation Safety Network ([ASN](https://asn.flightsafety.org/)). It focuses on data source scraping, collection steps and difficulties workarounds.

# %% [markdown]
# ---
# ## Table of Contents

# %% [markdown]
# ### Importing Libraries

# %% [markdown]
# Importing necessary Python libraries for web scraping, data processing, HTML parsing, and concurrent execution. These tools let us to collect and organize accident data efficiently.

# %%
import pandas as pd
import time
import requests
import re
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor

# %% [markdown]
# ### Web Scraping Process

# %%
headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/124.0.0.0 Safari/537.36"
    ),
    "Accept-Language": "en-US,en;q=0.9",
    "Referer": "https://asn.flightsafety.org/",
}

def get_soup(url, headers=None):
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return BeautifulSoup(response.text, 'html.parser')

# %%
def fetch_detail(link):
    row_extra = {}
    try:
        isoup = get_soup(link, headers=headers)
        rows = isoup.find("table").find_all("tr")
        for tr in rows:
            tds = tr.find_all("td")
            if len(tds) >= 2:
                key = tds[0].get_text(strip=True).rstrip(":")
                val = tds[1].get_text(strip=True)
                row_extra[key] = val

        locmap = isoup.find("iframe")
        if locmap and hasattr(locmap, "attrs"):
            src = locmap.attrs.get("src")
            if src:
                match = pattern.search(src)
                if match:
                    lat, lon = map(float, match.groups())
                    row_extra["ll"] = [lat, lon]
                    
    except Exception as e:
        row_extra["error"] = str(e)
    return row_extra

# %%
pattern = re.compile(r'll=([-.\d]+),([-.\d]+)')
data = []

year, page = 1995, 1

while year <= 2025:
    try:
        print(f"Scraping: https://asn.flightsafety.org/database/year/{year}/{page}")
        soup = get_soup(f"https://asn.flightsafety.org/database/year/{year}/{page}", headers=headers)

        table = soup.find("table", class_="hp")
        table_rows = table.find_all("tr")

        if year == 1995 and page == 1:
            columns = [th.text.strip() for th in table_rows[0].find_all("th")]
            print("Extracted table column headers")

        rows_data = []
        links_to_fetch = []

        for tr in table_rows[1:]:
            cols = tr.find_all("td")
            if not cols:
                continue

            row = {}
            link = None
            for i, td in enumerate(cols):
                text = td.get_text(strip=True)
                if i == 0:
                    a_tag = td.find("span")
                    if a_tag:
                        a = a_tag.find("a")
                        if a and "href" in a.attrs:
                            link = "https://asn.flightsafety.org" + a["href"]
                column = columns[i] if i < len(columns) else f"col_{i}"
                row[column] = text

            row["link"] = link
            if link:
                links_to_fetch.append((row, link))
            else:
                rows_data.append(row)

        print(f"Found {len(rows_data)} entries without detail links")
        print(f"Found {len(links_to_fetch)} entries with detail links")

        with ThreadPoolExecutor(max_workers=10) as executor:
            futures = {executor.submit(fetch_detail, link): row for row, link in links_to_fetch}
            for future in futures:
                row = futures[future]
                extra_data = future.result()
                row.update(extra_data)
                rows_data.append(row)

        data.extend(rows_data)
        print(f"Finished page {page} of year {year} — total records so far: {len(data)}")
        page += 1
        time.sleep(0.2)
        
    except Exception as e:
        if isinstance(e, AttributeError):
            print(f"Finished scraping year {year}")
        else:
            print(f"Error on year {year}, page {page}: {e}. Skipping to next year")
        year += 1
        page = 1

print("Scraping completed")
# Out:
# https://asn.flightsafety.org/database/year/1995/1
# https://asn.flightsafety.org/database/year/1995/2
# https://asn.flightsafety.org/database/year/1995/3
# https://asn.flightsafety.org/database/year/1995/4
# https://asn.flightsafety.org/database/year/1995/5
# Finished year 1995.
# https://asn.flightsafety.org/database/year/1996/1
# https://asn.flightsafety.org/database/year/1996/2
# https://asn.flightsafety.org/database/year/1996/3
# https://asn.flightsafety.org/database/year/1996/4
# https://asn.flightsafety.org/database/year/1996/5
# Finished year 1996.
# https://asn.flightsafety.org/database/year/1997/1
# https://asn.flightsafety.org/database/year/1997/2
# https://asn.flightsafety.org/database/year/1997/3
# https://asn.flightsafety.org/database/year/1997/4
# https://asn.flightsafety.org/database/year/1997/5
# Finished year 1997.
# https://asn.flightsafety.org/database/year/1998/1
# https://asn.flightsafety.org/database/year/1998/2
# https://asn.flightsafety.org/database/year/1998/3
# https://asn.flightsafety.org/database/year/1998/4
# https://asn.flightsafety.org/database/year/1998/5
# Finished year 1998.
# https://asn.flightsafety.org/database/year/1999/1
# https://asn.flightsafety.org/database/year/1999/2
# https://asn.flightsafety.org/database/year/1999/3
# https://asn.flightsafety.org/database/year/1999/4
# https://asn.flightsafety.org/database/year/1999/5
# Finished year 1999.
# https://asn.flightsafety.org/database/year/2000/1
# https://asn.flightsafety.org/database/year/2000/2
# https://asn.flightsafety.org/database/year/2000/3
# https://asn.flightsafety.org/database/year/2000/4
# https://asn.flightsafety.org/database/year/2000/5
# Finished year 2000.
# https://asn.flightsafety.org/database/year/2001/1
# https://asn.flightsafety.org/database/year/2001/2
# https://asn.flightsafety.org/database/year/2001/3
# https://asn.flightsafety.org/database/year/2001/4
# https://asn.flightsafety.org/database/year/2001/5
# Finished year 2001.
# https://asn.flightsafety.org/database/year/2002/1
# https://asn.flightsafety.org/database/year/2002/2
# https://asn.flightsafety.org/database/year/2002/3
# https://asn.flightsafety.org/database/year/2002/4
# Finished year 2002.
# https://asn.flightsafety.org/database/year/2003/1
# https://asn.flightsafety.org/database/year/2003/2
# https://asn.flightsafety.org/database/year/2003/3
# https://asn.flightsafety.org/database/year/2003/4
# Finished year 2003.
# https://asn.flightsafety.org/database/year/2004/1
# https://asn.flightsafety.org/database/year/2004/2
# https://asn.flightsafety.org/database/year/2004/3
# https://asn.flightsafety.org/database/year/2004/4
# Finished year 2004.
# https://asn.flightsafety.org/database/year/2005/1
# https://asn.flightsafety.org/database/year/2005/2
# https://asn.flightsafety.org/database/year/2005/3
# https://asn.flightsafety.org/database/year/2005/4
# Finished year 2005.
# https://asn.flightsafety.org/database/year/2006/1
# https://asn.flightsafety.org/database/year/2006/2
# https://asn.flightsafety.org/database/year/2006/3
# https://asn.flightsafety.org/database/year/2006/4
# https://asn.flightsafety.org/database/year/2006/5
# Finished year 2006.
# https://asn.flightsafety.org/database/year/2007/1
# https://asn.flightsafety.org/database/year/2007/2
# https://asn.flightsafety.org/database/year/2007/3
# https://asn.flightsafety.org/database/year/2007/4
# Finished year 2007.
# https://asn.flightsafety.org/database/year/2008/1
# https://asn.flightsafety.org/database/year/2008/2
# https://asn.flightsafety.org/database/year/2008/3
# https://asn.flightsafety.org/database/year/2008/4
# Finished year 2008.
# https://asn.flightsafety.org/database/year/2009/1
# https://asn.flightsafety.org/database/year/2009/2
# https://asn.flightsafety.org/database/year/2009/3
# https://asn.flightsafety.org/database/year/2009/4
# Finished year 2009.
# https://asn.flightsafety.org/database/year/2010/1
# https://asn.flightsafety.org/database/year/2010/2
# https://asn.flightsafety.org/database/year/2010/3
# https://asn.flightsafety.org/database/year/2010/4
# Finished year 2010.
# https://asn.flightsafety.org/database/year/2011/1
# https://asn.flightsafety.org/database/year/2011/2
# https://asn.flightsafety.org/database/year/2011/3
# https://asn.flightsafety.org/database/year/2011/4
# Finished year 2011.
# https://asn.flightsafety.org/database/year/2012/1
# https://asn.flightsafety.org/database/year/2012/2
# https://asn.flightsafety.org/database/year/2012/3
# https://asn.flightsafety.org/database/year/2012/4
# Finished year 2012.
# https://asn.flightsafety.org/database/year/2013/1
# https://asn.flightsafety.org/database/year/2013/2
# https://asn.flightsafety.org/database/year/2013/3
# https://asn.flightsafety.org/database/year/2013/4
# Finished year 2013.
# https://asn.flightsafety.org/database/year/2014/1
# https://asn.flightsafety.org/database/year/2014/2
# https://asn.flightsafety.org/database/year/2014/3
# https://asn.flightsafety.org/database/year/2014/4
# Finished year 2014.
# https://asn.flightsafety.org/database/year/2015/1
# https://asn.flightsafety.org/database/year/2015/2
# https://asn.flightsafety.org/database/year/2015/3
# https://asn.flightsafety.org/database/year/2015/4
# Finished year 2015.
# https://asn.flightsafety.org/database/year/2016/1
# https://asn.flightsafety.org/database/year/2016/2
# https://asn.flightsafety.org/database/year/2016/3
# https://asn.flightsafety.org/database/year/2016/4
# Finished year 2016.
# https://asn.flightsafety.org/database/year/2017/1
# https://asn.flightsafety.org/database/year/2017/2
# https://asn.flightsafety.org/database/year/2017/3
# https://asn.flightsafety.org/database/year/2017/4
# Finished year 2017.
# https://asn.flightsafety.org/database/year/2018/1
# https://asn.flightsafety.org/database/year/2018/2
# https://asn.flightsafety.org/database/year/2018/3
# https://asn.flightsafety.org/database/year/2018/4
# Finished year 2018.
# https://asn.flightsafety.org/database/year/2019/1
# https://asn.flightsafety.org/database/year/2019/2
# https://asn.flightsafety.org/database/year/2019/3
# https://asn.flightsafety.org/database/year/2019/4
# Finished year 2019.
# https://asn.flightsafety.org/database/year/2020/1
# https://asn.flightsafety.org/database/year/2020/2
# https://asn.flightsafety.org/database/year/2020/3
# https://asn.flightsafety.org/database/year/2020/4
# Finished year 2020.
# https://asn.flightsafety.org/database/year/2021/1
# https://asn.flightsafety.org/database/year/2021/2
# https://asn.flightsafety.org/database/year/2021/3
# https://asn.flightsafety.org/database/year/2021/4
# Finished year 2021.
# https://asn.flightsafety.org/database/year/2022/1
# https://asn.flightsafety.org/database/year/2022/2
# https://asn.flightsafety.org/database/year/2022/3
# https://asn.flightsafety.org/database/year/2022/4
# Finished year 2022.
# https://asn.flightsafety.org/database/year/2023/1
# https://asn.flightsafety.org/database/year/2023/2
# https://asn.flightsafety.org/database/year/2023/3
# https://asn.flightsafety.org/database/year/2023/4
# Finished year 2023.
# https://asn.flightsafety.org/database/year/2024/1
# https://asn.flightsafety.org/database/year/2024/2
# https://asn.flightsafety.org/database/year/2024/3
# https://asn.flightsafety.org/database/year/2024/4
# Finished year 2024.
# https://asn.flightsafety.org/database/year/2025/1
# https://asn.flightsafety.org/database/year/2025/2
# Finished year 2025.
# Completed.

# %% [markdown]
# ### Data Export
#
# - The resulting complete dataset is displayed for review.
# - Finally, the dataset is exported to a CSV file named `"full_asn_dataset"` with UTF-8 encoding, including column headers and excluding the DataFrame index.

# %%
df = pd.DataFrame(data)
df.head()

# %%
df.to_feather("full_asn_dataset.feather")
